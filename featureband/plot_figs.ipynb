# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Accuracy comparison

fb_perf = [0.861923076923077, 0.8384615384615384, 0.8057692307692308, 0.7849999999999999, 0.7665384615384615,
          0.7473076923076923, 0.7276923076923077, 0.7365384615384616, 0.7219230769230769, 0.7026923076923077]

ftest_perf = [0.8419230769230769, 0.7965384615384614, 0.7657692307692308, 0.7530769230769231, 0.7303846153846154,
             0.7096153846153846, 0.72, 0.7223076923076923, 0.7111538461538462, 0.7026923076923077]

mi_perf = [0.7734615384615384, 0.7457692307692307, 0.7115384615384616, 0.6880769230769233, 0.6976923076923077,
           0.6746153846153847, 0.6888461538461539, 0.6930769230769231, 0.6846153846153846, 0.7026923076923077]

chi2_perf = [0.7884615384615384, 0.7646153846153846, 0.7273076923076924, 0.7126923076923076, 0.7296153846153847,
0.7311538461538463, 0.721923076923077, 0.711923076923077, 0.7053846153846155, 0.7026923076923077]

percent = np.arange(10, 101, 10)

plt.plot(percent, fb_perf)
plt.plot(percent, ftest_perf)
plt.plot(percent, mi_perf)
plt.plot(percent, chi2_perf)

plt.xlabel("percent(%)")
plt.ylabel("accuracy")
plt.title("madelon knn")
plt.legend(labels=["ours", "ftest", "mutual_information", "chi2"])

plt.show()
# plt.savefig("log/madelon_knn.pdf")

# %%
# Robust of FeatureBand

plt.figure()

percent_10 = np.load("npdata/madelon_fb_50_knn.npz")["iter_best"]
percent_20 = np.load("npdata/madelon_fb_100_knn.npz")["iter_best"]
percent_30 = np.load("log/madelon_fb_30_knn.npz")["iter_best"]
percent_40 = np.load("log/madelon_fb_40_knn.npz")["iter_best"]

iteration = np.arange(50)

plt.plot(iteration, percent_10, linestyle='-')
plt.plot(iteration, percent_20[:50], linestyle='--')
plt.plot(iteration, percent_30[:50], linestyle='-.')
plt.plot(iteration, percent_40, linestyle=':')

# plt.title("Convergence process of our method")
plt.ylabel("accuracy")
plt.xlabel("iteration")
plt.ylim((0.65, 0.90))

plt.legend(labels=["10%", "20%", "30%", "40%"])

# plt.show()
# plt.savefig("figs/convergence.pdf")

# %%
# comparison with ga
import numpy as np
import matplotlib.pyplot as plt

madelon_ga_30_knn = np.load("npdata/usps_ga_100_knn.npz")
ga_times, ga_perfs = madelon_ga_30_knn["times"], madelon_ga_30_knn["global_best"]

madelon_fb_30_knn = np.load("npdata/usps_fb_100_knn.npz")
fb_times, fb_perfs = madelon_fb_30_knn["times"], madelon_fb_30_knn["global_best"]

ga_perfs = 1 - ga_perfs
fb_perfs = 1 - fb_perfs

print(fb_perfs[-1])
print(ga_perfs[-10:])

# plt.figure()
# plt.plot(fb_times, fb_perfs, linestyle='-')
# plt.plot(ga_times, ga_perfs, linestyle='--')

# plt.xlabel("time(s)")
# plt.ylabel("validation error")
# # plt.xlim((0, 500))
# # plt.ylim((0.8, 0.95))
# plt.legend(labels=["FB", "GA"])

# # plt.show()
# plt.savefig("figs/comparison_ga_usps.pdf")
# Out:
# 0.023297491039426577
# [0.0265233 0.0265233 0.0265233 0.0265233 0.0265233 0.0265233 0.0265233
#  0.0265233 0.0265233 0.0265233]

# %%
# Convergence of 
import numpy as np
import matplotlib.pyplot as plt

fb_random_10 = np.load("log/madelon_fbrandom_10_knn.npz")["iter_best"]
fb_random_20 = np.load("log/madelon_fbrandom_20_knn.npz")["iter_best"]
fb_random_30 = np.load("log/madelon_fbrandom_30_knn.npz")["iter_best"]
fb_random_40 = np.load("log/madelon_fbrandom_40_knn.npz")["iter_best"]

plt.plot(fb_random_10, linestyle='-')
plt.plot(fb_random_20, linestyle='--')
plt.plot(fb_random_30, linestyle='-.')
plt.plot(fb_random_40, linestyle=':')

plt.xlabel("iteration")
plt.ylabel("accuracy")
plt.ylim((0.65, 0.90))
plt.legend(labels=["10%", "20%", "30%", "40%"])

# plt.show()
plt.savefig("figs/random.pdf")

# %%
# madelon comparison with filter

import numpy as np
import matplotlib.pyplot as plt

plt.figure()

selected_features = np.arange(10, 101, 10)

madelon_fb = [0.8903846153846153, 0.8780769230769231, 0.8823076923076922, 0.8703846153846154, 0.8611538461538462, 
               0.8546153846153846, 0.8596153846153847, 0.8465384615384615, 0.828076923076923, 0.8288461538461538]

madelon_ftest = [0.85692308, 0.87384615, 0.855,      0.83692308, 0.82807692, 0.81,
                 0.79884615, 0.79307692, 0.78576923, 0.77961538]

madelon_mi = [0.6065384615384615, 0.6134615384615384, 0.6761538461538462, 0.6684615384615384, 0.64,
              0.6403846153846154, 0.6315384615384615, 0.6515384615384615, 0.6507692307692308, 0.6646153846153846]

madelon_mrmr = [0.52,       0.54038462, 0.53076923, 0.51615385, 0.52923077, 0.53961538,
 0.53461538, 0.52769231, 0.52961538, 0.535     ]

madelon_cmim = [0.78615385, 0.78423077, 0.75038462, 0.73961538, 0.74153846, 0.73538462,
 0.71615385, 0.71269231, 0.69846154, 0.70538462]

# madelon_ccm = [0.85692308, 0.87384615, 0.85461538, 0.835, 0.83038462, 0.81192308,
#  0.79807692, 0.79269231, 0.78961538, 0.78076923]

madelon_ccm = [0.83038462, 0.85384615, 0.82846154, 0.83076923, 0.825,      0.80615385,
 0.80576923, 0.79576923, 0.78769231, 0.77192308]

madelon_rf = [0.8565384615384616, 0.8680769230769231, 0.851153846153846, 0.825, 0.8126923076923076,
0.8084615384615385, 0.7984615384615384, 0.7896153846153846, 0.7861538461538461, 0.7842307692307692]

plt.plot(selected_features, madelon_fb, marker='o')
plt.plot(selected_features, madelon_ftest, marker='.')
plt.plot(selected_features, madelon_mi, marker='*')
plt.plot(selected_features, madelon_mrmr, marker='v')
plt.plot(selected_features, madelon_cmim, marker='^', linestyle='--')
plt.plot(selected_features, madelon_ccm, marker='<', linestyle='-.')
plt.plot(selected_features, madelon_rf, marker='>', linestyle=':')

plt.ylim((0, 1))
plt.legend(labels=["FB", "F-test", "MI", "MRMR", "CMIM", "CCM", "RF"], loc="lower right")

plt.show()
# plt.savefig("figs/madelon_comparison.pdf")

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure()

selected_features = np.arange(10, 101, 10)

basehock_fb = [0.8304072523878967, 0.8534951989545652, 0.883575437333889, 0.862044279464404, 0.8720819681445426, 
              0.8630366849112706, 0.8730491215444152, 0.87607684197900297, 0.8871246125389038, 0.8866006325637773]

basehock_ftest = [0.7707177263056886, 0.8324072145098261, 0.8494624470496139, 0.8685201669160307, 0.9031647127895305,
        0.9001521435831391, 0.9016735794145312, 0.9016761046192308, 0.9046886738256219, 0.9036937431740559]

basehock_mi = [0.8625505830066349, 0.891651041962589, 0.8926560734329527, 0.8986812118457352, 0.8961850470003725,
0.8936737309268132, 0.8835931137667847, 0.8921775471424154, 0.8911674652626529, 0.8911750408767511]

basehock_mrmr = [0.87106179, 0.90267356, 0.91422006, 0.91221505, 0.91922501, 0.92323756,
                 0.91772631, 0.91823261, 0.91873386, 0.91773388]

basehock_cmim = [0.87659072, 0.88713219, 0.89415983, 0.89215482, 0.8936611,  0.880626,
 0.87761848, 0.88714734, 0.88261333, 0.88110705]

basehock_ccm = [0.65028061, 0.71550918, 0.73757189, 0.74159202, 0.74504776, 0.7485439,
 0.76461431, 0.78724898, 0.79175773, 0.79626396]

basehock_rf = [0.8735655259054436, 0.8800969678604572, 0.8821221820293808, 0.8876233404670366, 0.8966458968580142,
0.8981572318706086, 0.8941446816032524, 0.897152200400245, 0.896645896858014, 0.8936358528563222]


# basehock_original = [0.8595077113438508] * 10

plt.plot(selected_features, basehock_fb, marker='o')
plt.plot(selected_features, basehock_ftest, marker='.')
plt.plot(selected_features, basehock_mi, marker='*')
plt.plot(selected_features, basehock_mrmr, marker='v')
plt.plot(selected_features, basehock_cmim, marker='^')
plt.plot(selected_features, basehock_ccm, marker='<')
plt.plot(selected_features, basehock_rf, marker='>')
plt.legend(labels=["FB", "F-test", "MI", "MRMR", "CMIM", "CCM", "RF"], loc="lower right")
# plt.ylim((0.2, 1))

# plt.show()
plt.savefig("figs/basehock_comparison.pdf")

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure()

selected_features = np.arange(10, 101, 10)

coil20_fb = [0.8042380952380952, 0.8682857142857143, 0.8713333333333333, 0.8915714285714286, 0.9049523809523808, 
            0.9037142857142857, 0.9019999999999999, 0.892, 0.902952380952381, 0.8866190476190475]

coil20_ftest = [0.19042857142857145, 0.47223809523809523, 0.6894285714285715, 0.7661904761904762, 0.8127142857142857,
                0.8366190476190475, 0.8573809523809525, 0.862952380952381, 0.8671428571428571, 0.8716190476190476]

coil20_mi = [0.586047619047619, 0.7146190476190476, 0.7533809523809524, 0.7783333333333333, 0.7995238095238095, 
0.8091904761904761, 0.8212380952380952, 0.8233809523809524, 0.8281904761904763, 0.8324761904761905]

coil20_mrmr = [0.6472381, 0.74119048, 0.79952381, 0.80971429, 0.81614286, 0.83290476,
 0.82780952, 0.83609524, 0.84295238, 0.84028571]

coil20_cmim = [0.78615385, 0.78423077, 0.75038462, 0.73961538, 0.74153846, 0.73538462,
 0.71615385, 0.71269231, 0.69846154, 0.70538462]

coil20_ccm = [0.43885714, 0.59795238, 0.60680952, 0.66319048, 0.70190476, 0.71190476,
 0.72804762, 0.75928571, 0.78547619, 0.807 ]

coil20_rf = [0.7444285714285714, 0.8124285714285714, 0.8496666666666666, 0.8492380952380951, 0.8617619047619047,
0.8666190476190477, 0.8846666666666667, 0.8853809523809524, 0.9000952380952383, 0.9091904761904763]

plt.plot(selected_features, coil20_fb, marker='o')
plt.plot(selected_features, coil20_ftest, marker='.')
plt.plot(selected_features, coil20_mi, marker='*')
plt.plot(selected_features, coil20_mrmr, marker='v')
plt.plot(selected_features, coil20_cmim, marker='^')
plt.plot(selected_features, coil20_ccm, marker='<')
plt.plot(selected_features, coil20_rf, marker='>')
plt.legend(labels=["FB", "F-test", "MI", "MRMR", "CMIM", "CCM", "RF"])

# plt.show()
plt.savefig("figs/coil20_comparison.pdf")

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure()

selected_features = np.arange(10, 101, 10)

usps_fb = [0.8895273695818926, 0.9499662523556427, 0.9573901389292925, 0.9613708528807743, 0.9635217432261308,
          0.967395732544462, 0.9651358034054432, 0.9684690411609701, 0.967722363783834, 0.9666430371520087]

usps_ftest = [0.6224634975757539, 0.7882079207336343, 0.842626732407917, 0.8915771114975689, 0.8974953967177054, 
0.9100812992132241, 0.930186123627481, 0.939214579010858, 0.9479268312057118, 0.955564160825457]

usps_mi = [0.5702406404747945, 0.634412035629304, 0.6820679004268608, 0.7001265668229792, 0.7342268063173538, 
0.7790858956598045, 0.8523128050504301, 0.8721044209584866, 0.8826458951167133, 0.8940459847997012]

usps_mrmr = [0.3446542,  0.47049706, 0.51265401, 0.56008997, 0.60277804, 0.64935539,
 0.68151877, 0.71990265, 0.74465462, 0.78939752]

usps_cmim = [0.61296802, 0.80961362, 0.89867472, 0.93685233, 0.94771338, 0.95029613,
 0.95008363, 0.95212434, 0.95395601, 0.95653539]

usps_ccm = [0.66302156, 0.79839209, 0.83871141, 0.86605866, 0.88804004, 0.90372136,
 0.91037824, 0.91704732, 0.9303672,  0.94003624]

usps_rf = [0.7282122432116194, 0.8858782995346131, 0.9330899271647473, 0.9414793622318859, 0.9478231279059477,
0.9512653835285704, 0.9556753898134221, 0.9561009797774428, 0.9553492143326784, 0.9582546485144187]


plt.plot(selected_features, usps_fb, marker='o')
plt.plot(selected_features, usps_ftest, marker='.')
plt.plot(selected_features, usps_mi, marker='*')
plt.plot(selected_features, usps_mrmr, marker='v')
plt.plot(selected_features, usps_cmim, marker='^')
plt.plot(selected_features, usps_ccm, marker='<')
plt.plot(selected_features, usps_rf, marker='>')

# plt.plot(selected_features, usps_original, "--", linewidth=2)
plt.legend(labels=["FB", "F-test", "MI", "MRMR", "CMIM", "CCM", "RF"])

# plt.show()
plt.savefig("figs/usps_comparison.pdf")

# %%
# time complexity
import numpy as np
import matplotlib.pyplot as plt

sfs_time = [62.50948700000001, 167.21841999999998, 308.957676, 489.040637, 709.192231, 
            978.434289, 1312.020014, 1727.708894, 2242.386259, 2812.615602]
sffs_time = [87.500269, 190.04835699999998, 329.142879, 1363.818736, 1897.059295,
            2518.029981, 6656.498649, 10026.624402, 11724.285151, 18236.733058]

fb_time = []
for i in np.arange(10, 101, 10):
    fname = "npdata/madelon_fb_" + str(i) + "_knn.npz"
    fb_time.append(np.load(fname)["times"][49])

fb_time = np.array(fb_time)    
sfs_time = np.array(sfs_time)
sffs_time = np.array(sffs_time)

selected_features = np.arange(10, 101, 10)

# sfs_time = sfs_time / fb_time
# sffs_time = sffs_time / fb_time

plt.figure()

# selected_features = np.arange(10, 101, 10)


x = np.arange(len(fb_time))

total_width, n = 0.8, 3
width = total_width / n
x = x - (total_width - width) / 2

print(fb_time)

plt.bar(x, fb_time,  width=width, label='FB', color="lightgrey")
plt.bar(x + width, sfs_time, width=width, label='SFS', tick_label=np.arange(10, 101, 10), color="dimgrey")
plt.bar(x + 2 * width, sffs_time, width=width, label='SFFS', color="black")
plt.legend()

# plt.show()
plt.savefig("figs/time_wrapper.pdf")

# plt.figure()
# plt.plot(np.arange(10, 101, 10), sffs_time)

# plt.show()
# Out:
# [ 182.462187    263.621324    336.682196    406.891286    489.44097567
#   607.067725    703.364395    801.676351    913.284603   1033.69213533]

# %%
# madelon logistic
import numpy as np
import matplotlib.pyplot as plt

plt.figure()

selected_features = np.arange(10, 101, 10)

madelon_fb = [0.6046153846153846, 0.5903846153846154, 0.5842307692307692, 0.5903846153846154, 0.5961538461538461,
            0.573076923076923, 0.5769230769230769, 0.5788461538461539, 0.6, 0.5596153846153846]

madelon_ftest = [0.6065384615384616, 0.5907692307692307, 0.583076923076923, 0.5900000000000001, 0.5696153846153846,
                 0.571923076923077, 0.5653846153846155, 0.5669230769230769, 0.5611538461538462, 0.5742307692307692]

madelon_mi = [0.6123076923076923, 0.5923076923076923, 0.5926923076923077, 0.595, 0.5942307692307692,
              0.5853846153846154, 0.5823076923076923, 0.5776923076923077, 0.5750000000000001, 0.5715384615384617]

madelon_mrmr = [0.55, 0.55, 0.5403846153846154, 0.5230769230769231, 0.5365384615384615,
                0.5576923076923077, 0.5480769230769231, 0.55, 0.5442307692307692, 0.5442307692307692]

madelon_cmim = [0.59230769, 0.6,        0.59807692, 0.60192308, 0.60576923, 0.60576923,
 0.6,        0.58461538, 0.58461538, 0.58269231]

madelon_ccm = [0.60653846, 0.59076923, 0.58192308, 0.58576923, 0.56423077, 0.57153846,
 0.56230769, 0.565,      0.56807692, 0.57115385]

madelon_rf = [0.6111538461538462, 0.6046153846153846, 0.6080769230769232, 0.6011538461538461, 0.5953846153846155,
0.5915384615384616, 0.5888461538461539, 0.5907692307692308, 0.5892307692307692, 0.5923076923076923]

# coil20_original = [0.8995714285714286] * 10

plt.plot(selected_features, madelon_fb, marker='o')
plt.plot(selected_features, madelon_ftest, marker='.')
plt.plot(selected_features, madelon_mi, marker='*')
plt.plot(selected_features, madelon_mrmr, marker='v')
plt.plot(selected_features, madelon_cmim, marker='^')
plt.plot(selected_features, madelon_ccm, marker='<')
plt.plot(selected_features, madelon_rf, marker='>')


plt.legend(labels=["FB", "F-test", "MI", "MRMR", "CMIM", "CCM", "RF"], loc="lower right")
plt.ylim((0.45, 0.62))
plt.show()
# plt.savefig("figs/madelon_logistic.pdf")

# %%
# basehock logistic
import numpy as np
import matplotlib.pyplot as plt

plt.figure()

selected_features = np.arange(10, 101, 10)

basehock_fb = [0.8471177944862155, 0.8822055137844611, 0.8972431077694235, 0.8847117794486216, 0.8646616541353384,
            0.8771929824561403, 0.8972431077694235, 0.8671679197994987, 0.8972431077694235, 0.8596491228070176]

basehock_ftest = [0.8048408174087612, 0.8580014267406553, 0.8810615960556302, 0.8996104871751166, 0.9277336919124007,
0.9367638239174763, 0.9453103792226157, 0.9468166638258113, 0.9493254546946712, 0.9488267267665386]

basehock_mi = [0.870049178361521, 0.9051874017537547, 0.909207527635209, 0.9152225652291939, 0.9172275777605222, 
0.9202451973763124, 0.9202426721716129, 0.9212477036419765, 0.9267564376937305, 0.9252501530905348]

basehock_mrmr = [0.8721804511278195, 0.9047619047619048, 0.9147869674185464, 0.9022556390977443, 0.9122807017543859,
0.924812030075188, 0.924812030075188, 0.9398496240601504, 0.9147869674185464, 0.9172932330827067]

basehock_cmim = [0.87218045, 0.89724311, 0.90726817, 0.9047619,  0.9197995,  0.92982456,
 0.9122807,  0.92230576, 0.92230576, 0.92481203]

basehock_ccm = [0.68688977, 0.73105812, 0.75211833, 0.7586422,  0.77672771, 0.78927419,
 0.79780055, 0.80230425, 0.80882812, 0.81434443]

basehock_rf = [0.8891144738420358, 0.9237539693061368, 0.9377915822301345, 0.9448066008850841, 0.9488216763571398,
0.9533354797573278, 0.9538367328901598, 0.9538392580948593, 0.9548367139511246, 0.9548417643605236]

# coil20_original = [0.8995714285714286] * 10

plt.plot(selected_features, basehock_fb, marker='o')
plt.plot(selected_features, basehock_ftest, marker='.')
plt.plot(selected_features, basehock_mi, marker='*')
plt.plot(selected_features, basehock_mrmr, marker='v')
plt.plot(selected_features, basehock_cmim, marker='^')
plt.plot(selected_features, basehock_ccm, marker='<')
plt.plot(selected_features, basehock_rf, marker='>')


plt.legend(labels=["FB", "F-test", "MI", "MRMR", "CMIM", "CCM", "RF"], loc="lower right")
# plt.ylim((0.45, 0.62))
# plt.show()
plt.savefig("figs/basehock_logistic.pdf")

# %%
# coil20 logistic
import numpy as np
import matplotlib.pyplot as plt

plt.figure()

selected_features = np.arange(10, 101, 10)

coil20_fb = [0.7133333333333334, 0.75, 0.8566666666666667, 0.81, 0.83,
            0.8333333333333334, 0.88, 0.8566666666666667, 0.8266666666666667, 0.9]

coil20_ftest = [0.16014285714285711, 0.33280952380952383, 0.4861428571428571, 0.5988571428571429, 0.6517619047619048,
0.6839999999999999, 0.7102380952380952, 0.714, 0.741142857142857, 0.7496190476190476]

coil20_mi = [0.388, 0.5105238095238095, 0.5634761904761905, 0.6152857142857142, 0.6398095238095238,
0.667, 0.6727142857142857, 0.6771904761904762, 0.7160952380952381, 0.722047619047619]


coil20_mrmr = [0.51, 0.6133333333333333, 0.6666666666666666, 0.7166666666666667,
0.7066666666666667, 0.77, 0.76, 0.7566666666666667, 0.78, 0.79]

coil20_cmim = [0.59230769, 0.6,        0.59807692, 0.60192308, 0.60576923, 0.60576923,
 0.6,        0.58461538, 0.58461538, 0.58269231]

coil20_ccm = [0.23552381, 0.38309524, 0.41857143, 0.47985714, 0.51047619, 0.53157143,
 0.5572381,  0.58642857, 0.64580952, 0.68514286]

coil20_rf = [0.6144761904761904, 0.6672380952380952, 0.7156190476190477, 0.7625714285714286, 0.7910476190476191,
0.789047619047619, 0.8213809523809523, 0.8364285714285714, 0.8486190476190476, 0.8562380952380952]

plt.plot(selected_features, coil20_fb, marker='o')
plt.plot(selected_features, coil20_ftest, marker='.')
plt.plot(selected_features, coil20_mi, marker='*')
plt.plot(selected_features, coil20_mrmr, marker='v')
plt.plot(selected_features, coil20_cmim, marker='^')
plt.plot(selected_features, coil20_ccm, marker='<')
plt.plot(selected_features, coil20_rf, marker='>')


# plt.plot(selected_features, coil20_original, "--", linewidth=2)
# plt.legend(labels=["FB", "F-test", "MI", "MRMR", "CMIM", "Without feature selection"])
plt.legend(labels=["FB", "F-test", "MI", "MRMR", "CMIM", "CCM", "RF"], loc="lower right")
# plt.ylim((0.45, 0.62))
# plt.show()
plt.savefig("figs/coil20_logistic.pdf")

# %%
# usps logistic
import numpy as np
import matplotlib.pyplot as plt

plt.figure()

selected_features = np.arange(10, 101, 10)

usps_fb = [0.8540772532188842, 0.9125536480686696, 0.9302575107296137, 0.9409871244635193, 0.944206008583691,
            0.9484978540772532, 0.9436695278969958, 0.9474248927038627, 0.950107296137339, 0.9495708154506438]

usps_ftest = [0.5432135044517243, 0.7337955614881326, 0.7991713702176243, 0.8698429636924289, 0.8795212283640336,
0.8885560475027287, 0.9037153099145341, 0.9108152289007128, 0.9188845152380258, 0.9267369048462376]

usps_mi = [0.45364280487376785, 0.5241819347641222, 0.5810880266899365, 0.6137770012244604, 0.653992146791706,
0.7566207601321262, 0.843605961754265, 0.8651140898549341, 0.8781268393142124, 0.8840510273078529]


usps_mrmr = [0.3310085836909871, 0.4071888412017167, 0.4565450643776824, 0.5048283261802575, 0.5402360515021459,
0.625, 0.6561158798283262, 0.7017167381974249, 0.7628755364806867, 0.7913090128755365]

usps_cmim = [0.5498927,  0.78648069, 0.85783262, 0.91630901, 0.92811159, 0.93347639,
 0.93562232, 0.94045064, 0.94313305, 0.94366953]

usps_ccm = [0.65237421, 0.78241218, 0.82501852, 0.85134355, 0.86470323, 0.87670697,
 0.88533507, 0.89602402, 0.91070438, 0.91935241]

usps_rf = [0.6907856810125317, 0.8585528427556121, 0.8964092483445404, 0.9109251964020352, 0.9213650556600239,
0.9248043073794878, 0.9277071993898586, 0.9284593021133674, 0.9300745244822636, 0.9302899274747893]

plt.plot(selected_features, usps_fb, marker='o')
plt.plot(selected_features, usps_ftest, marker='.')
plt.plot(selected_features, usps_mi, marker='*')
plt.plot(selected_features, usps_mrmr, marker='v')
plt.plot(selected_features, usps_cmim, marker='^')
plt.plot(selected_features, usps_ccm, marker='<')
plt.plot(selected_features, usps_rf, marker='>')

# plt.plot(selected_features, coil20_original, "--", linewidth=2)
# plt.legend(labels=["FB", "F-test", "MI", "MRMR", "CMIM", "Without feature selection"])
plt.legend(labels=["FB", "F-test", "MI", "MRMR", "CMIM", "CCM", "RF"], loc="lower right")
# plt.ylim((0.45, 0.62))
# plt.show()
plt.savefig("figs/usps_logistic.pdf")
